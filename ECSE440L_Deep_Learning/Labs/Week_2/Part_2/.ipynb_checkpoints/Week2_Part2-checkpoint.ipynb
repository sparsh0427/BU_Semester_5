# %% [markdown]
# # Lab 2 Part 2

# %% [markdown]
# ### Part a) Data Wrangling:

# %% [markdown]
# #### Importing Packages

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn import preprocessing #For normalizing
from sklearn.model_selection import train_test_split # For training testing data
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1. Dataset:

# %%
data = pd.read_csv('dataset.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# #### 2. Missing Data:

# %%
data.isnull()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %% [markdown]
# ####  3. Categorize:

# %%
def categorize(row):
    if(row['Sales'] >= 15):
        return "high"
    elif(row['Sales'] < 15 and row['Sales'] >= 5):
        return "medium"
    else:
        return "low"

data.apply(lambda row: categorize(row), axis=1)
# Out:
# 0        high
# 1      medium
# 2      medium
# 3        high
# 4      medium
#         ...
# 195    medium
# 196    medium
# 197    medium
# 198      high
# 199    medium
# Length: 200, dtype: object

# %% [markdown]
# ####  4. Concatenation

# %%
data['Sales Type'] = data.apply(lambda row: categorize(row), axis=1)
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales Sales Type
# 0             1  230.1   37.8       69.2   22.1       high
# 1             2   44.5   39.3       45.1   10.4     medium
# 2             3   17.2   45.9       69.3    9.3     medium
# 3             4  151.5   41.3       58.5   18.5       high
# 4             5  180.8   10.8       58.4   12.9     medium
# ..          ...    ...    ...        ...    ...        ...
# 195         196   38.2    3.7       13.8    7.6     medium
# 196         197   94.2    4.9        8.1    9.7     medium
# 197         198  177.0    9.3        6.4   12.8     medium
# 198         199  283.6   42.0       66.2   25.5       high
# 199         200  232.1    8.6        8.7   13.4     medium
#
# [200 rows x 6 columns]

# %% [markdown]
# #### 5. Groupby and Aggregation:

# %%
data_group = data.groupby('Sales Type')
data_group.first()
# Out:
#             Unnamed: 0     TV  Radio  Newspaper  Sales
# Sales Type
# high                 1  230.1   37.8       69.2   22.1
# low                  9    8.6    2.1        1.0    4.8
# medium               2   44.5   39.3       45.1   10.4

# %%
print("TV sum = ",data['TV'].sum())
print("TV mean = ",data['TV'].sum())
print("Newspaper sum = ",data['Newspaper'].sum())
print("Newspaper mean = ",data['Newspaper'].sum())
print("Radio sum = ",data['Radio'].sum())
print("Radio mean = ",data['Radio'].sum())
# Out:
# TV sum =  29408.5
# TV mean =  29408.5
# Newspaper sum =  6110.799999999999
# Newspaper mean =  6110.799999999999
# Radio sum =  4652.800000000001
# Radio mean =  4652.800000000001

# %% [markdown]
# #### 6. Reshaping and Pivoting:

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales Sales Type
# 0           1  230.1   37.8       69.2   22.1       high
# 1           2   44.5   39.3       45.1   10.4     medium
# 2           3   17.2   45.9       69.3    9.3     medium
# 3           4  151.5   41.3       58.5   18.5       high
# 4           5  180.8   10.8       58.4   12.9     medium

# %%
df_stacked = data.stack() 
print(df_stacked.head(26))
# Out:
# 0  Unnamed: 0         1
#    TV             230.1
#    Radio           37.8
#    Newspaper       69.2
#    Sales           22.1
#    Sales Type      high
# 1  Unnamed: 0         2
#    TV              44.5
#    Radio           39.3
#    Newspaper       45.1
#    Sales           10.4
#    Sales Type    medium
# 2  Unnamed: 0         3
#    TV              17.2
#    Radio           45.9
#    Newspaper       69.3
#    Sales            9.3
#    Sales Type    medium
# 3  Unnamed: 0         4
#    TV             151.5
#    Radio           41.3
#    Newspaper       58.5
#    Sales           18.5
#    Sales Type      high
# 4  Unnamed: 0         5
#    TV             180.8
# dtype: object

# %%
df_unstacked = df_stacked.unstack() 
print(df_unstacked.head(10))
# Out:
#   Unnamed: 0     TV Radio Newspaper Sales Sales Type
# 0          1  230.1  37.8      69.2  22.1       high
# 1          2   44.5  39.3      45.1  10.4     medium
# 2          3   17.2  45.9      69.3   9.3     medium
# 3          4  151.5  41.3      58.5  18.5       high
# 4          5  180.8  10.8      58.4  12.9     medium
# 5          6    8.7  48.9        75   7.2     medium
# 6          7   57.5  32.8      23.5  11.8     medium
# 7          8  120.2  19.6      11.6  13.2     medium
# 8          9    8.6   2.1         1   4.8        low
# 9         10  199.8   2.6      21.2  10.6     medium

# %% [markdown]
# ### Part b) Data Modeling:

# %% [markdown]
# #### 7. Dataset:

# %%
data = pd.read_csv('dataset.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#Selecting every 6th row from column "TV"
data.loc[data.index % 6 == 0,'TV']
# Out:
# 0      230.1
# 6       57.5
# 12      23.8
# 18      69.2
# 24      62.3
# 30     292.9
# 36     266.9
# 42     293.6
# 48     227.2
# 54     262.7
# 60      53.5
# 66      31.5
# 72      26.8
# 78       5.4
# 84     213.5
# 90     134.3
# 96     197.6
# 102    280.2
# 108     13.1
# 114     78.2
# 120    141.3
# 126      7.8
# 132      8.4
# 138     43.0
# 144     96.2
# 150    280.7
# 156     93.9
# 162    188.4
# 168    215.4
# 174    222.4
# 180    156.6
# 186    139.5
# 192     17.2
# 198    283.6
# Name: TV, dtype: float64

# %%
#Replacing every 6th row of column TV with NaN Values
data.loc[data.index % 6 == 0,'TV'] = np.nan
data.head(20)
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 0            1    NaN   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7    NaN   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13    NaN   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19    NaN   20.5       18.3   11.3
# 19          20  147.3   23.9       19.1   14.6

# %%
# Similarly selecting 10th row of coloumn Newspaper and replacing with NaN value
data.loc[data.index % 10 == 0,'Newspaper'] = np.nan
data.head(20)
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 0            1    NaN   37.8        NaN   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7    NaN   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8        NaN    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13    NaN   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19    NaN   20.5       18.3   11.3
# 19          20  147.3   23.9       19.1   14.6

# %%
# Printing only rows containing no Nan/NULL value.
is_NaN = data.isnull()
row_has_NaN = is_NaN.any(axis=1)
data.loc[row_has_NaN == False].head(20)
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 11          12  214.7   24.0        4.0   17.4
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 19          20  147.3   23.9       19.1   14.6
# 21          22  237.4    5.1       23.5   12.5
# 22          23   13.2   15.9       49.6    5.6
# 23          24  228.3   16.9       26.2   15.5
# 25          26  262.9    3.5       19.5   12.0
# 26          27  142.9   29.3       12.6   15.0

# %% [markdown]
# #### 8. Fill in missing values:

# %%
# Fill missing(NaN/NULL) values with 0
data_0 = data.replace(np.nan,0)
data_0.head(25)
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 0            1    0.0   37.8        0.0   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7    0.0   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8        0.0    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13    0.0   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19    0.0   20.5       18.3   11.3
# 19          20  147.3   23.9       19.1   14.6
# 20          21  218.4   27.7        0.0   18.0
# 21          22  237.4    5.1       23.5   12.5
# 22          23   13.2   15.9       49.6    5.6
# 23          24  228.3   16.9       26.2   15.5
# 24          25    0.0   12.6       18.3    9.7

# %%
# Fill missing(NaN/NULL) values with average of column
X = data.iloc[:, :].values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imputer.fit(X[:,:])
X[:,:] = imputer.transform(X[:,:])
data = pd.DataFrame(data=X, index=list(range(X.shape[0])), columns=['Unnamed: 0','TV','Radio','Newspaper','Sales'])
data.head(25)
# Out:
#     Unnamed: 0          TV  Radio   Newspaper  Sales
# 0          1.0  148.757831   37.8   30.492222   22.1
# 1          2.0   44.500000   39.3   45.100000   10.4
# 2          3.0   17.200000   45.9   69.300000    9.3
# 3          4.0  151.500000   41.3   58.500000   18.5
# 4          5.0  180.800000   10.8   58.400000   12.9
# 5          6.0    8.700000   48.9   75.000000    7.2
# 6          7.0  148.757831   32.8   23.500000   11.8
# 7          8.0  120.200000   19.6   11.600000   13.2
# 8          9.0    8.600000    2.1    1.000000    4.8
# 9         10.0  199.800000    2.6   21.200000   10.6
# 10        11.0   66.100000    5.8   30.492222    8.6
# 11        12.0  214.700000   24.0    4.000000   17.4
# 12        13.0  148.757831   35.1   65.900000    9.2
# 13        14.0   97.500000    7.6    7.200000    9.7
# 14        15.0  204.100000   32.9   46.000000   19.0
# 15        16.0  195.400000   47.7   52.900000   22.4
# 16        17.0   67.800000   36.6  114.000000   12.5
# 17        18.0  281.400000   39.6   55.800000   24.4
# 18        19.0  148.757831   20.5   18.300000   11.3
# 19        20.0  147.300000   23.9   19.100000   14.6
# 20        21.0  218.400000   27.7   30.492222   18.0
# 21        22.0  237.400000    5.1   23.500000   12.5
# 22        23.0   13.200000   15.9   49.600000    5.6
# 23        24.0  228.300000   16.9   26.200000   15.5
# 24        25.0  148.757831   12.6   18.300000    9.7

# %% [markdown]
# #### 9. Normalization:

# %%
x = data.loc[:,data.columns != 'Sales'].values #normalizing is not done in target variable
y = data.iloc[:,4] # target variable to be added later in the dataframe
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
data = pd.DataFrame(x_scaled, index=list(range(x.shape[0])), columns=['Unnamed: 0','TV','Radio','Newspaper'])
data.insert(4, "Sales", y, True)
data.head(25)
# Out:
#     Unnamed: 0        TV     Radio  Newspaper  Sales
# 0     0.000000  0.500703  0.762097   0.265543   22.1
# 1     0.005025  0.148123  0.792339   0.394019   10.4
# 2     0.010050  0.055800  0.925403   0.606860    9.3
# 3     0.015075  0.509976  0.832661   0.511873   18.5
# 4     0.020101  0.609063  0.217742   0.510994   12.9
# 5     0.025126  0.027054  0.985887   0.656992    7.2
# 6     0.030151  0.500703  0.661290   0.204046   11.8
# 7     0.035176  0.404126  0.395161   0.099384   13.2
# 8     0.040201  0.026716  0.042339   0.006157    4.8
# 9     0.045226  0.673318  0.052419   0.183817   10.6
# 10    0.050251  0.221170  0.116935   0.265543    8.6
# 11    0.055276  0.723706  0.483871   0.032542   17.4
# 12    0.060302  0.500703  0.707661   0.576957    9.2
# 13    0.065327  0.327359  0.153226   0.060686    9.7
# 14    0.070352  0.687859  0.663306   0.401935   19.0
# 15    0.075377  0.658438  0.961694   0.462621   22.4
# 16    0.080402  0.226919  0.737903   1.000000   12.5
# 17    0.085427  0.949273  0.798387   0.488127   24.4
# 18    0.090452  0.500703  0.413306   0.158311   11.3
# 19    0.095477  0.495773  0.481855   0.165347   14.6
# 20    0.100503  0.736219  0.558468   0.265543   18.0
# 21    0.105528  0.800473  0.102823   0.204046   12.5
# 22    0.110553  0.042273  0.320565   0.433597    5.6
# 23    0.115578  0.769699  0.340726   0.227792   15.5
# 24    0.120603  0.500703  0.254032   0.158311    9.7

# %% [markdown]
# #### 10. Data Splitting:

# %%
x = data[['TV','Radio','Newspaper']] #Features
y = data['Sales'].values # Target Variable
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.60, random_state=42)

# %% [markdown]
# #### 11. Linear Regression Training:

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(x_test)

# %%
#Predictions
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#     Actual  Predicted
# 0     16.9  16.661176
# 1     22.4  21.533670
# 2     21.4  15.216996
# 3      7.3  10.901878
# 4     24.7  22.746648
# ..     ...        ...
# 75    15.9  16.257140
# 76    15.0  15.096390
# 77    20.7  20.056379
# 78    11.7  13.448137
# 79    21.8  21.453464
#
# [80 rows x 2 columns]

# %%
# Plot for True value vs Predicted value
df1 = df.head(25)
df1.plot(kind='bar',figsize=(15,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# #### 12. Testing error:

# %%
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 9.250575159224704

# %% [markdown]
# #### 13. Playing with the Model:

# %%
#Reducing the number of features
x = data[['TV','Radio']] #Features
y = data['Sales'].values # Target Variable
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.60, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(x_test)

# %%
#Predictions
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#     Actual  Predicted
# 0     16.9  16.593179
# 1     22.4  21.494520
# 2     21.4  15.228622
# 3      7.3  10.876267
# 4     24.7  22.898666
# ..     ...        ...
# 75    15.9  16.328696
# 76    15.0  15.178138
# 77    20.7  20.205527
# 78    11.7  13.414097
# 79    21.8  21.508635
#
# [80 rows x 2 columns]

# %%
# Plot for True value vs Predicted value
df1 = df.head(25)
df1.plot(kind='bar',figsize=(15,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 9.215070516232808
